# %%
import requests
import pandas as pd
import numpy as np
import json

# %%
url = "https://swapi.co/api/people"

# %%
JSONContent = requests.get(url).json()

# %%
content = json.dumps(JSONContent, indent=4, sort_keys=True)

# %%
print(content)
# Out:
# {
#     "count": 87,
#     "next": "https://swapi.co/api/people/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "birth_year": "19BBY",
#             "created": "2014-12-09T13:50:51.644000Z",
#             "edited": "2014-12-20T21:17:56.891000Z",
#             "eye_color": "blue",
#             "films": [
#                 "https://swapi.co/api/films/2/",
#                 "https://swapi.co/api/films/6/",
#                 "https://swapi.co/api/films/3/",
#                 "https://swapi.co/api/films/1/",
#                 "https://swapi.co/api/films/7/"
#             ],
#             "gender": "male",
#             "hair_color": "blond",
#             "height": "172",
#             "homeworld": "https://swapi.co/api/planets/1/",
#             "mass": "77",
#             "name": "Luke Skywalker",
#             "skin_color": "fair",
#             "species": [
#                 "https://swapi.co/api/species/1/"
#             ],
# ...

# %%
liste=[]

# %%
for i in range(1,11):
    url = requests.get(f"https://swapi.co/api/people/{i}")
    s= url.json()
    liste.append(s)

# %%
df = pd.DataFrame(liste)
df
# Out:
#   birth_year                      created                       edited  \
# 0      19BBY  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1     112BBY  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2      33BBY  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3    41.9BBY  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4      19BBY  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5      52BBY  2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6      47BBY  2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 7    unknown  2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 8      24BBY  2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9      57BBY  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#    eye_color                                              films  gender  \
# 0       blue  [https://swapi.co/api/films/2/, https://swapi....    male
# ...

# %%
df = df[['name','height','mass','hair_color','skin_color','eye_color','birth_year','gender','homeworld','films','species']]
df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                         homeworld  \
# 0      19BBY    male   https://swapi.co/api/planets/1/
# ...

# %%
df.columns
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'gender', 'homeworld', 'films', 'species'],
#       dtype='object')

# %%
for i in range(len(df.films)):
    df.films[i]=df.films[i][0]
    df.species[i]=df.species[i][0]
df
# Out:
# /Users/Mary/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# ...
